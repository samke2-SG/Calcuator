# %%
from tkinter import* # It is the standard Python interface to the Tk GUI toolkit #GUI -Graphical User Interface

#creating a variable
calc=Tk() 

#code for FRAME of calculator:
#width and height of calculator
calc.geometry("300x445")  
#cannot maximize size of calculator
calc.resizable(0,0) 
#title of calculator 
calc.title("Nadine and Sisamkele Calculator")  
#title of calculator 
calclabel = Label(calc,text="Worlds Best Calculator",bg='pink',font=("Arial",21,))
#position of label
calclabel.pack(side=TOP)
#backound color of calculator
calc.config(background='white')

#stores user input 
textin=StringVar() 
#user input text bar
txtDisplay =Entry(calc,textvariable = textin,bd=5,width=45,bg="light grey")
#position of text bar
txtDisplay.pack()

operator=""
def clickbut(number):
     #returns the dictionary representing the global namespace of the module(function)
     global operator
     #adds math operator to the input(number)
     operator=operator+str(number)
     #whatver is typed in will be printed
     textin.set(operator)
#function created when user presses equal button
def equlbut():
     global operator
     #regognition of the operation
     #program regognizes what operator user types in
     add=str(eval(operator))
     textin.set(add)
     operator=''
def equlbut():
     global operator
     sub=str(eval(operator))
     textin.set(sub)
     operator=''     
def equlbut():
     global operator
     mul=str(eval(operator))
     textin.set(mul)
     operator=''
def equlbut():
     global operator
     div=str(eval(operator))
     textin.set(div)
     operator=''    
#function created when user presses clear button
def clrbut():
     #no value will be printed
     textin.set('')
    
#user input text bar
txtDisplay =Entry(calc,textvariable = textin,bd=5,width=45,bg="light grey")
#position of text bar
txtDisplay.pack()

#creating each button: bd = width border, fg = text color
button0 = Button(calc,padx=16,pady=16,bd=8,text="0",command=lambda:clickbut(0),fg="black",bg="light pink")
#position of button
button0.place(x=17,y=279)

button1 = Button(calc,padx=16,pady=16,bd=9,text="1",command=lambda:clickbut(1),fg="black",bg="light pink")
button1.place(x=17,y=209)

button2 = Button(calc,padx=16,pady=16,bd=9,text="2",command=lambda:clickbut(2),fg="black",bg="light pink")
button2.place(x=82,y=209)

button3 = Button(calc,padx=16,pady=16,bd=9,text="3",command=lambda:clickbut(3),fg="black",bg="light pink")
button3.place(x=147,y=209)

button4 = Button(calc,padx=16,pady=16,bd=9,text="4",command=lambda:clickbut(4),fg="black",bg="light pink")
button4.place(x=17,y=139)

button5 = Button(calc,padx=16,pady=16,bd=9,text="5",command=lambda:clickbut(5),fg="black",bg="light pink")
button5.place(x=82,y=139)

button6 = Button(calc,padx=16,pady=16,bd=9,text="6",command=lambda:clickbut(6),fg="black",bg="light pink")
button6.place(x=147,y=139)

button7 = Button(calc,padx=16,pady=16,bd=9,text="7",command=lambda:clickbut(7),fg="black",bg="light pink")
button7.place(x=17,y=69)

button8 = Button(calc,padx=16,pady=16,bd=9,text="8",command=lambda:clickbut(8),fg="black",bg="light pink")
button8.place(x=82,y=69)

button9 = Button(calc,padx=16,pady=16,bd=9,text="9",command=lambda:clickbut(9),fg="black",bg="light pink")
button9.place(x=147,y=69)

buttonadd = Button(calc,padx=16,pady=16,bd=9,text="+",command=lambda:clickbut("+"),fg="black",bg="light pink")
buttonadd.place(x=212,y=69)

buttonmul = Button(calc,padx=17,pady=16,bd=9,text="x",command=lambda:clickbut("*"),fg="black",bg="light pink")
buttonmul.place(x=212,y=209)

buttonsub = Button(calc,padx=17,pady=16,bd=9,text="-",command=lambda:clickbut("-"),fg="black",bg="light pink")
buttonsub.place(x=212,y=139)

buttondiv = Button(calc,padx=16,pady=16,bd=9,text="/",command=lambda:clickbut("/"),fg="black",bg="light pink")
buttondiv.place(x=147,y=280)

buttonequal = Button(calc,padx=79,pady=16,bd=9,text="=",command=equlbut,fg="black",bg="light pink")
buttonequal.place(x=17,y=354)

buttondot = Button(calc,padx=16,pady=16,bd=9,text=".",command=lambda:clickbut("."),fg="black",bg="light pink")
buttondot.place(x=82,y=279)

buttonclr = Button(calc,padx=16,pady=54,bd=9,text="C",command=clrbut,fg="black",bg="light pink")
buttonclr.place(x=212,y=279)

       

#call variable 
calc.mainloop()
